# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import os

# %%
train_trans = pd.read_csv("../data/raw/train_transaction.csv")
train_id = pd.read_csv("../data/raw/train_identity.csv")

# %%
df = train_trans.merge(train_id, on="TransactionID", how="left")
print(df.shape)
# Out:
# (590540, 434)

# %%
missing_pct = df.isnull().mean()
cols_to_drop = missing_pct[missing_pct > 0.9].index
df.drop(columns=cols_to_drop, inplace=True)

# %%
df
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400           68.50         W
# 1             2987001        0          86401           29.00         W
# 2             2987002        0          86469           59.00         W
# 3             2987003        0          86499           50.00         W
# 4             2987004        0          86506           50.00         H
# ...               ...      ...            ...             ...       ...
# 590535        3577535        0       15811047           49.00         W
# 590536        3577536        0       15811049           39.50         W
# 590537        3577537        0       15811079           30.95         W
# 590538        3577538        0       15811088          117.00         W
# 590539        3577539        0       15811131          279.95         W
#
#         card1  card2  card3       card4  card5  ...                id_31  \
# 0       13926    NaN  150.0    discover  142.0  ...                  NaN
# 1        2755  404.0  150.0  mastercard  102.0  ...                  NaN
# 2        4663  490.0  150.0        visa  166.0  ...                  NaN
# 3       18132  567.0  150.0  mastercard  117.0  ...                  NaN
# 4        4497  514.0  150.0  mastercard  102.0  ...  samsung browser 6.2
# ...       ...    ...    ...         ...    ...  ...                  ...
# 590535   6550    NaN  150.0        visa  226.0  ...                  NaN
# 590536  10444  225.0  150.0  mastercard  224.0  ...                  NaN
# 590537  12037  595.0  150.0  mastercard  224.0  ...                  NaN
# 590538   7826  481.0  150.0  mastercard  224.0  ...                  NaN
# 590539  15066  170.0  150.0  mastercard  102.0  ...                  NaN
#
#         id_32      id_33           id_34 id_35 id_36  id_37  id_38  \
# 0         NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 1         NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 2         NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 3         NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 4        32.0  2220x1080  match_status:2     T     F      T      T
# ...       ...        ...             ...   ...   ...    ...    ...
# 590535    NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 590536    NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 590537    NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 590538    NaN        NaN             NaN   NaN   NaN    NaN    NaN
# 590539    NaN        NaN             NaN   NaN   NaN    NaN    NaN
#
#         DeviceType                     DeviceInfo
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2              NaN                            NaN
# 3              NaN                            NaN
# 4           mobile  SAMSUNG SM-G892A Build/NRD90M
# ...            ...                            ...
# 590535         NaN                            NaN
# 590536         NaN                            NaN
# 590537         NaN                            NaN
# 590538         NaN                            NaN
# 590539         NaN                            NaN
#
# [590540 rows x 422 columns]

# %%
for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].fillna("missing")
    else:
        df[col] = df[col].fillna(-999)

# %%
df
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400           68.50         W
# 1             2987001        0          86401           29.00         W
# 2             2987002        0          86469           59.00         W
# 3             2987003        0          86499           50.00         W
# 4             2987004        0          86506           50.00         H
# ...               ...      ...            ...             ...       ...
# 590535        3577535        0       15811047           49.00         W
# 590536        3577536        0       15811049           39.50         W
# 590537        3577537        0       15811079           30.95         W
# 590538        3577538        0       15811088          117.00         W
# 590539        3577539        0       15811131          279.95         W
#
#         card1  card2  card3       card4  card5  ...                id_31  \
# 0       13926 -999.0  150.0    discover  142.0  ...              missing
# 1        2755  404.0  150.0  mastercard  102.0  ...              missing
# 2        4663  490.0  150.0        visa  166.0  ...              missing
# 3       18132  567.0  150.0  mastercard  117.0  ...              missing
# 4        4497  514.0  150.0  mastercard  102.0  ...  samsung browser 6.2
# ...       ...    ...    ...         ...    ...  ...                  ...
# 590535   6550 -999.0  150.0        visa  226.0  ...              missing
# 590536  10444  225.0  150.0  mastercard  224.0  ...              missing
# 590537  12037  595.0  150.0  mastercard  224.0  ...              missing
# 590538   7826  481.0  150.0  mastercard  224.0  ...              missing
# 590539  15066  170.0  150.0  mastercard  102.0  ...              missing
#
#         id_32      id_33           id_34    id_35    id_36    id_37    id_38  \
# 0      -999.0    missing         missing  missing  missing  missing  missing
# 1      -999.0    missing         missing  missing  missing  missing  missing
# 2      -999.0    missing         missing  missing  missing  missing  missing
# 3      -999.0    missing         missing  missing  missing  missing  missing
# 4        32.0  2220x1080  match_status:2        T        F        T        T
# ...       ...        ...             ...      ...      ...      ...      ...
# 590535 -999.0    missing         missing  missing  missing  missing  missing
# 590536 -999.0    missing         missing  missing  missing  missing  missing
# 590537 -999.0    missing         missing  missing  missing  missing  missing
# 590538 -999.0    missing         missing  missing  missing  missing  missing
# 590539 -999.0    missing         missing  missing  missing  missing  missing
#
#         DeviceType                     DeviceInfo
# 0          missing                        missing
# 1          missing                        missing
# 2          missing                        missing
# 3          missing                        missing
# 4           mobile  SAMSUNG SM-G892A Build/NRD90M
# ...            ...                            ...
# 590535     missing                        missing
# 590536     missing                        missing
# 590537     missing                        missing
# 590538     missing                        missing
# 590539     missing                        missing
#
# [590540 rows x 422 columns]

# %%
df.to_csv("../data/processed/cleaned_data.csv", index=False)
